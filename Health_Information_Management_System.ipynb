# %% [markdown]
# <a href="https://colab.research.google.com/github/dharmendra-chouhan/Pandas_exercises_colab/blob/master/Health_Information_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-768c4951-2fe2-42d6-a5c8-b7824d889aa1" name="files[]" multiple disabled />
#      <output id="result-768c4951-2fe2-42d6-a5c8-b7824d889aa1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DATA 01 TO 03  NOV 20191.csv to DATA 01 TO 03  NOV 20191.csv

# %%
import pandas as pd
hmisdata= pd.read_csv('DATA 01 TO 03  NOV 20191.csv', sep=',', encoding='latin-1')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,7,9,10,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
hmisdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725732 entries, 0 to 725731
# Data columns (total 20 columns):
# FacilityCode     725732 non-null int64
# FacilityName     725732 non-null object
# FTypeShort       717236 non-null object
# FtypeCat         725595 non-null object
# CityName         725732 non-null object
# VisitCode        725732 non-null object
# OrderID          725732 non-null object
# PatCode          725732 non-null object
# GENDER           725658 non-null object
# Age              725730 non-null object
# ServiceCode      725732 non-null object
# ServiceName      725732 non-null object
# ItemName         725732 non-null object
# Result           689558 non-null object
# Abnormal Flag    711020 non-null object
# Unnamed: 15      83682 non-null object
# Unnamed: 16      2637 non-null object
# Unnamed: 17      8 non-null object
# Unnamed: 18      3 non-null object
# Unnamed: 19      1 non-null object
# dtypes: int64(1), object(19)
# memory usage: 110.7+ MB

# %%
hmisdata.head(5)
# Out:
#    FacilityCode       FacilityName  ... Unnamed: 18 Unnamed: 19
# 0             1  Manchar (100 Bed)  ...         NaN         NaN
# 1             1  Manchar (100 Bed)  ...         NaN         NaN
# 2             1  Manchar (100 Bed)  ...         NaN         NaN
# 3             1  Manchar (100 Bed)  ...         NaN         NaN
# 4             1  Manchar (100 Bed)  ...         NaN         NaN
#
# [5 rows x 20 columns]

# %% [markdown]
# **Extra column(s) found with Data**
#
# Unnamed: 15 -     83682
#
# Unnamed: 16  -    2637
#
# Unnamed: 17  -    8
#
# Unnamed: 18   -   3
#
# Unnamed: 19  -    1

# %%
hmisdata.isnull().sum()
# Out:
# FacilityCode          0
# FacilityName          0
# FTypeShort         8496
# FtypeCat            137
# CityName              0
# VisitCode             0
# OrderID               0
# PatCode               0
# GENDER               74
# Age                   2
# ServiceCode           0
# ServiceName           0
# ItemName              0
# Result            36174
# Abnormal Flag     14712
# Unnamed: 15      642050
# Unnamed: 16      723095
# Unnamed: 17      725724
# Unnamed: 18      725729
# Unnamed: 19      725731
# dtype: int64

# %% [markdown]
# **Missing Data**
# ____________________________________
# FTypeShort    -      8496
#
# FtypeCat      -      137
#
# GENDER       -        74
#
# Age           -          2
# _____________________________________

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(hmisdata)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %% [markdown]
# **Observations :**
#
# 1.   Total 725732 rows with 20 columns data received

# %%
hmisdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725732 entries, 0 to 725731
# Data columns (total 20 columns):
# FacilityCode     725732 non-null int64
# FacilityName     725732 non-null object
# FTypeShort       717236 non-null object
# FtypeCat         725595 non-null object
# CityName         725732 non-null object
# VisitCode        725732 non-null object
# OrderID          725732 non-null object
# PatCode          725732 non-null object
# GENDER           725658 non-null object
# Age              725730 non-null object
# ServiceCode      725732 non-null object
# ServiceName      725732 non-null object
# ItemName         725732 non-null object
# Result           689558 non-null object
# Abnormal Flag    711020 non-null object
# Unnamed: 15      83682 non-null object
# Unnamed: 16      2637 non-null object
# Unnamed: 17      8 non-null object
# Unnamed: 18      3 non-null object
# Unnamed: 19      1 non-null object
# dtypes: int64(1), object(19)
# memory usage: 110.7+ MB

# %%
# creating GENDER series True for NaN values  
hmisdata_nullgender = pd.isnull(hmisdata['GENDER'])  
    
# displaying data only with Gender = NaN  
hmisdata[hmisdata_nullgender]
# Out:
#         FacilityCode                FacilityName  ... Unnamed: 18 Unnamed: 19
# 136165           499  District Hospital Bhandara  ...         NaN         NaN
# 136482           499  District Hospital Bhandara  ...         NaN         NaN
# 136706           499  District Hospital Bhandara  ...         NaN         NaN
# 136961           499  District Hospital Bhandara  ...         NaN         NaN
# 175263           654              Rh Barshitakli  ...         NaN         NaN
# ...              ...                         ...  ...         ...         ...
# 680700          2796                        Uphc  ...         NaN         NaN
# 680705          2796                        Uphc  ...         NaN         NaN
# 689838          2848                 Uphc Gondia  ...         NaN         NaN
# 689845          2848                 Uphc Gondia  ...         NaN         NaN
# 689882          2848                 Uphc Gondia  ...         NaN         NaN
#
# [74 rows x 20 columns]

# %% [markdown]
# Find and Replace Gender

# %%
df=  hmisdata['Age']=='M'
hmisdata[df]  


import pandas as pd


df = pd.DataFrame(df, columns = ['GENDER','Age'])

# Values to find and their replacements
findL = ['Australia', 'Mexico', 'United States', 'hob']
replaceL = ['Kangaroo', 'Spider Monkey', 'Eagle', 'Test']

# Select column (can be A,B,C,D)
col = 'GENDER';

# Find and replace values in the selected column
df[col] = df[col].replace(findL, replaceL)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-2854efa8a552> in <module>()
#       1 df['GENDER'] =  hmisdata['Age']=='M'
# ----> 2 hmisdata[df]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# ...

# %%
hmisdata.head()
# Out:
#    FacilityCode       FacilityName  ... Unnamed: 18 Unnamed: 19
# 0             1  Manchar (100 Bed)  ...         NaN         NaN
# 1             1  Manchar (100 Bed)  ...         NaN         NaN
# 2             1  Manchar (100 Bed)  ...         NaN         NaN
# 3             1  Manchar (100 Bed)  ...         NaN         NaN
# 4             1  Manchar (100 Bed)  ...         NaN         NaN
#
# [5 rows x 20 columns]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = hmisdata.columns
y_pos = np.arange(len(objects))
# objects

performance = hmisdata.count().values

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation=90)
plt.ylabel('Usage')
plt.title('Total 725732 rows with 20 columns data received')

plt.show()
hmisdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725732 entries, 0 to 725731
# Data columns (total 20 columns):
# FacilityCode     725732 non-null int64
# FacilityName     725732 non-null object
# FTypeShort       717236 non-null object
# FtypeCat         725595 non-null object
# CityName         725732 non-null object
# VisitCode        725732 non-null object
# OrderID          725732 non-null object
# PatCode          725732 non-null object
# GENDER           725658 non-null object
# Age              725730 non-null object
# ServiceCode      725732 non-null object
# ServiceName      725732 non-null object
# ItemName         725732 non-null object
# Result           689558 non-null object
# Abnormal Flag    711020 non-null object
# Unnamed: 15      83682 non-null object
# Unnamed: 16      2637 non-null object
# Unnamed: 17      8 non-null object
# Unnamed: 18      3 non-null object
# Unnamed: 19      1 non-null object
# dtypes: int64(1), object(19)
# memory usage: 110.7+ MB
